# %% [markdown]
# # Add data from in-game

# %%
import pandas as pd

# %%
path_to_csv = '../../data/raw/s9.csv'

df = pd.read_csv(path_to_csv)

# %%
# <h1>MAINSTAYS<h1>

#%%%%% Strikers %%%%%#
# - hoshino
# - tshiroko
# - haruka
# - iori
# - reisa
# - marina
# - saori
# - eimi
# - tsurugi
# - shun
# - nyharuna
# - nymutsuki
# - shanako

#%%%%% Specials %%%%%#
# - sshiroko
# - hibiki
# - nagisa
# - sayane
# - saki
# - sayane
# - sayane
# - hibiki
# - minori
# - nyserika

# %%
### ADD ATK DATA
new_row = ['indoor', 'atk',
           
            # DEFENSE
            'haruka', # d1
            'tshiroko', # d2
            'hoshino', # d3
            'iori', # d4

            'nagisa', # ds1
            'sshiroko', # always shiroko ds2

            # ATTACK
            'marina', # a1
            'tshiroko', # a2
            'shun', # a3
            'hoshino', # a4

            'sayane', # as1
            'sshiroko', # always shiroko as2

            1, # did you win?
            'na' # rank (after atking)
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)

# %%
### ADD DEF DATA
new_row = ['indoor','def',
           
            # DEFENSE
            'tshiroko', # d1
            'iori', # d2
            'shun', # d3
            'hoshino', # d4

            'sayane', # ds1
            'sshiroko', # always shiroko ds2

            # ATTACK
            'iori', # a1
            'marina', # a2
            'tshiroko', # a3
            'hoshino', # a4

            'nagisa', # as1
            'sshiroko', # always shiroko as2

            1, # did you win?
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)
