# %%
import pandas as pd

# %%
df = pd.read_csv('../s9/data/s9.csv')

uniques = set(df['d1'].unique().tolist() + df['d2'].unique().tolist() + df['d3'].unique().tolist() + df['d4'].unique().tolist()\
+ df['a1'].unique().tolist() + df['a2'].unique().tolist() + df['a3'].unique().tolist() + df['a4'].unique().tolist())

uniques
# Out:
# {'azusa',
#  'haruka',
#  'hoshino',
#  'iori',
#  'junko',
#  'marina',
#  'mika',
#  'miyako',
#  'nyharuna',
#  'nymutsuki',
#  'reisa',
#  'shanako',
#  'shun',
#  'sumire',
#  'tshiroko',
#  'tsubaki',
#  'tsurugi',
#  'yuuka'}

# %%
uniques = set(df['as1'].unique().tolist()+df['ds1'].unique().tolist())

# %%
# table of all common strikers and attributes, also ex skill stuffs
# NOTES: scaled to ue60 standard, max everything

striker_attributes = pd.DataFrame([
    # TSHIROKO
    {'char': 'tshiroko', 'atk_type': 'blue', 'def_type': 'blue', 'role': 'dealer', 'weapon': 'ar', 'position': 'middle',
     'invul': 'yes', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 3, 'ex_length': 3.33, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'A', 'role': 'striker', 'alt_count': 0,
     'max_hp': 69289, 'atk': 6276, 'def': 108, 'dmg_reduction': 0.0609, 'healing': 5932, 'accuracy': 709,
     'evasion': 1239, 'crit': 733, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1380,
     'min_dmg': 0.7798, 'stability_rate': 0.2, 'n_range': 650, 's_range': 800, 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 15, 'na_cost': 3},

    # HOSHINO
    {'char': 'hoshino', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # IORI
    {'char': 'iori', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # AZUSA
    {'char': 'azusa', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # SHUN
    {'char': 'shun', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # MARINA
    {'char': 'marina', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # SHANAKO
    {'char': 'shanako', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # NYMUTSUKI
    {'char': 'nymutsuki', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # nyharuna
    {'char': 'nyharuna', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # reisa
    {'char': 'reisa', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # haruka
    {'char': 'haruka', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # sumire
    {'char': 'sumire', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # yuuka
    {'char': 'yuuka', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # miyako
    {'char': 'miyako', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # mika
    {'char': 'mika', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # tsurugi
    {'char': 'tsurugi', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # tsubaki
    {'char': 'tsubaki', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # junko
    {'char': 'junko', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # eimi
    {'char': 'eimi', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # bneru
    {'char': 'bneru', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # atsuko
    {'char': 'atsuko', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # yuzu
    {'char': 'yuzu', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},

    # shoshino
    {'char': 'shoshino', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'tank', 'weapon': 'sg', 'position': 'front',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 4, 'ex_length': 7.63, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'SS', 'affinity_indoor':'B', 'role': 'striker', 'alt_count': 2,
     'max_hp': 111386, 'atk': 4757, 'def': 2792, 'dmg_reduction': 0.6262, 'healing': 7077, 'accuracy': 615, 
     'evasion': 246, 'crit': 505, 'crit_res': 520, 'crit_dmg': 2.0, 'crit_dmg_res': 1.0, 'stability': 1948, 
     'min_dmg': 0.8608, 'stability_rate': 0.2, 'n_range': 350, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': 8, 'na_cost': 1},




])
striker_attributes
# Out:
#          char atk_type def_type     role weapon position invul deals_dmg  \
# 0    tshiroko     blue     blue  striker     ar   middle   yes       yes
# 1     hoshino   yellow   yellow  striker     sg    front    no       yes
# 2        iori   yellow   yellow  striker     sg    front    no       yes
# 3       azusa   yellow   yellow  striker     sg    front    no       yes
# 4        shun   yellow   yellow  striker     sg    front    no       yes
# 5      marina   yellow   yellow  striker     sg    front    no       yes
# 6     shanako   yellow   yellow  striker     sg    front    no       yes
# 7   nymutsuki   yellow   yellow  striker     sg    front    no       yes
# 8    nyharuna   yellow   yellow  striker     sg    front    no       yes
# 9       reisa   yellow   yellow  striker     sg    front    no       yes
# 10     haruka   yellow   yellow  striker     sg    front    no       yes
# 11     sumire   yellow   yellow  striker     sg    front    no       yes
# ...

# %%
# table of all common supporters and attributes

special_attributes = pd.DataFrame([
    # SSHIROKO
    {'char': 'sshiroko', 'atk_type': 'blue', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 3, 'ex_length': 4.93, 'generates_cost': 'yes',
     'affinity_urban': 'B', 'affinity_outdoor': 'SS', 'affinity_indoor':'D', 'role': 'support', 'alt_count': 2,
     'max_hp': 43517, 'atk': 8150, 'def': 2060, 'dmg_reduction': '?', 'healing': 8069, 'accuracy': 660,
     'evasion': 786, 'crit': 734, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1582,
     'min_dmg': 0.8127, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'},
     
    # SAYANE
    {'char': 'sayane', 'atk_type': 'yellow', 'def_type': 'red', 'role': 'ts', 'weapon': '?', 'position': 'back',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 4, 'ex_length': 14.53, 'generates_cost': 'no',
     'affinity_urban': 'A', 'affinity_outdoor': 'A', 'affinity_indoor':'B', 'role': 'support', 'alt_count': 1,
     'max_hp': 46530, 'atk': 7493, 'def': 1804, 'dmg_reduction': '?', 'healing': 8526, 'accuracy': 1160,
     'evasion': 191, 'crit': 1241, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 2194,
     'min_dmg': 0.8869, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'},

    # SAKI
    {'char': 'saki', 'atk_type': 'yellow', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 4, 'ex_length': 7.00, 'generates_cost': 'no',
     'affinity_urban': 'SS', 'affinity_outdoor': 'D', 'affinity_indoor':'B', 'role': 'support', 'alt_count': 1,
     'max_hp': 41990, 'atk': 8970, 'def': 2132, 'dmg_reduction': '?', 'healing': 11438, 'accuracy': 101,
     'evasion': 197, 'crit': 202, 'crit_res': 100, 'crit_dmg': 2.2, 'crit_dmg_res': 0.5, 'stability': 1582,
     'min_dmg': 0.8127, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 186, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # NAGISA
    {'char': 'nagisa', 'atk_type': 'red', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'yes', 'heals': 'yes', 'ex_cost': 3, 'ex_length': 6.83, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor':'SS', 'role': 'support', 'alt_count': 1,
     'max_hp': 44099, 'atk': 7734, 'def': 2061, 'dmg_reduction': '?', 'healing': 11519, 'accuracy': 759, 
     'evasion': 977, 'crit': 682, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1132, 
     'min_dmg': 0.731, 'stability_rate': 0.2, 'n_range': 1000, 's_range': 800, 'cc_power': 100, 'cc_res': 100, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # RIO
    {'char': 'rio', 'atk_type': 'blue', 'def_type': '?', 'role': 'support', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'no', 'heals': 'no', 'ex_cost': 2, 'ex_length': 6.70, 'generates_cost': 'no',
     'affinity_urban': 'A', 'affinity_outdoor': 'D', 'affinity_indoor':'SS', 'role': 'support', 'alt_count': 0,
     'max_hp': 67546, 'atk': 5691, 'def': 599, 'dmg_reduction': '?', 'healing': 7564, 'accuracy': 714,
     'evasion': 1151, 'crit': 868, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1201,
     'min_dmg': 0.7457, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # HIBIKI
    {'char': 'hibiki', 'atk_type': 'red', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 4, 'ex_length': 4.00, 'generates_cost': 'no',
     'affinity_urban': 'SS', 'affinity_outdoor': 'B', 'affinity_indoor': 'B', 'role': 'support', 'alt_count': 1,
     'max_hp': 43506, 'atk': 7070, 'def': 437, 'dmg_reduction': '?', 'healing': 7437, 'accuracy': 500, 
     'evasion': 201, 'crit': 831, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1141, 
     'min_dmg': 0.7329, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 136, 
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # MINORI
    {'char': 'minori', 'atk_type': 'red', 'def_type': '?', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 4, 'ex_length': 4.80, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor': 'SS', 'role': 'support', 'alt_count': 0,
     'max_hp': 43678, 'atk': 8106, 'def': 2062, 'dmg_reduction': '?', 'healing': 8023, 'accuracy': 656,
     'evasion': 791, 'crit': 732, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1592,
     'min_dmg': 0.8142, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # IROHA
    {'char': 'iroha', 'atk_type': 'blue', 'def_type': 'yellow', 'role': 'ts', 'weapon': '?', 'position': 'back',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 6, 'ex_length': 19.17, 'generates_cost': 'no',
     'affinity_urban': 'D', 'affinity_outdoor': 'B', 'affinity_indoor': 'SS', 'role': 'support', 'alt_count': 0,
     'max_hp': 58232, 'atk': 7278, 'def': 110, 'dmg_reduction': '?', 'healing': 7903, 'accuracy': 896,
     'evasion': 650, 'crit': 728, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 2309,
     'min_dmg': 0.8978, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.35, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0,
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # NYSERIKA
    {'char': 'nyserika', 'atk_type': 'yellow', 'def_type': '?', 'role': 'support', 'weapon': '?', 'position': 'back',
     'invul': '?', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 3, 'ex_length': 5.77, 'generates_cost': 'no',
     'affinity_urban': 'C', 'affinity_outdoor': 'C', 'affinity_indoor': 'SS', 'role': 'support', 'alt_count': 2,
     'max_hp': 71981, 'atk': 5944, 'def': 1800, 'dmg_reduction': '?', 'healing': 8663, 'accuracy': 763,
     'evasion': 727, 'crit': 698, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1463,
     'min_dmg': 0.794, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 100,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # UTAHA
    {'char': 'utaha', 'atk_type': 'yellow', 'def_type': 'yellow', 'role': 'dealer', 'weapon': '?', 'position': 'back',
     'invul': 'no', 'deals_dmg': 'yes', 'heals': 'no', 'ex_cost': 4, 'ex_length': 4.00, 'generates_cost': 'no',
     'affinity_urban': 'A', 'affinity_outdoor': 'B', 'affinity_indoor': 'A', 'role': 'support', 'alt_count': 1,
     'max_hp': 46592, 'atk': 6449, 'def': 112, 'dmg_reduction': '?', 'healing': 7665, 'accuracy': 318,
     'evasion': 1176, 'crit': 1375, 'crit_res': 100, 'crit_dmg': 2.26, 'crit_dmg_res': 0.5, 'stability': 1638,
     'min_dmg': 0.8209, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 136,
     'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.2, 'mov_spd': '?', 'block_rate_bonus': 0.0, 
     'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, 

    # ...
])

special_attributes
# Out:
#        char atk_type def_type     role weapon position invul deals_dmg heals  \
# 0  sshiroko     blue        ?  support      ?     back     ?       yes    no
# 1    sayane   yellow      red  support      ?     back    no       yes    no
# 2      saki   yellow        ?  support      ?     back     ?       yes    no
# 3    nagisa      red        ?  support      ?     back     ?       yes   yes
# 4       rio     blue        ?  support      ?     back     ?        no    no
# 5    hibiki      red        ?  support      ?     back     ?       yes    no
# 6    minori      red        ?  support      ?     back     ?       yes    no
# 7     iroha     blue   yellow  support      ?     back    no       yes    no
# 8  nyserika   yellow        ?  support      ?     back     ?       yes    no
# 9     utaha   yellow   yellow  support      ?     back    no       yes    no
#
#    ex_cost  ...  cc_power cc_res recov_boost cost_recovery atk_spd  mov_spd  \
# ...

# %%
# affinity

affinity_map = pd.DataFrame([
    {'affinity':'SS', "dmg_mult": 1.3, "block_r": 0.75},
    {'affinity':'S', "dmg_mult": 1.2, "block_r": 0.60},
    {'affinity':'A', "dmg_mult": 1.1, "block_r": 0.45},
    {'affinity':'B', "dmg_mult": 1.0, "block_r": 0.30},
    {'affinity':'C', "dmg_mult": 0.9, "block_r": 0.15},
    {'affinity':'D', "dmg_mult": 0.8, "block_r": 0.00},
])

affinity_map
# Out:
#   affinity  dmg_mult  block_r
# 0       SS       1.3     0.75
# 1        S       1.2     0.60
# 2        A       1.1     0.45
# 3        B       1.0     0.30
# 4        C       0.9     0.15
# 5        D       0.8     0.00

# %%
# color effectiveness

# %% [markdown]
# paste
#
# follow this exact structure, only replacing the dict's values with these new values pasted below: FORMAT: 'max_hp': 43517, 'atk': 8150, 'def': 2060, 'dmg_reduction': '?', 'healing': 8069, 'accuracy': 660, 'evasion': 786, 'crit': 734, 'crit_res': 100, 'crit_dmg': 2.46, 'crit_dmg_res': 0.5, 'stability': 1582, 'min_dmg': 0.8127, 'stability_rate': 0.2, 'n_range': 1000, 's_range': '?', 'cc_power': 100, 'cc_res': 100, 'recov_boost': 0.0, 'cost_recovery': 700, 'atk_spd': 1.0, 'mov_spd': 200, 'block_rate_bonus': 0.0, 'def_piercing': 0, 'mag_count': '?', 'na_cost': '?'}, VALUES:
