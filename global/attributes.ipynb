# %%
import pandas as pd

# %%
df = pd.read_csv('../s9/data/s9.csv')

d1 = df[]
# Out:
#     affinity type        d1        d2        d3        d4              ds  \
# 0     indoor  def   hoshino  Tshiroko    haruka      iori   ayane_shiroko
# 1     indoor  def   hoshino  Tshiroko    haruka      iori   ayane_shiroko
# 2     indoor  def   hoshino  Tshiroko    haruka      iori   ayane_shiroko
# 3     indoor  atk    marina  Tshiroko      shun   hoshino   ayane_shiroko
# 4     indoor  atk      shun   hoshino  Tshiroko      iori  nagisa_shiroko
# ..       ...  ...       ...       ...       ...       ...             ...
# 329   indoor  atk  Tshiroko    marina      shun   hoshino  nagisa_shiroko
# 330   indoor  atk    marina  Tshiroko   hoshino      iori  nagisa_shiroko
# 331   indoor  atk      iori    marina   hoshino  Tshiroko  hibiki_shiroko
# 332   indoor  atk      shun    marina   hoshino      iori   ayane_shiroko
# 333   indoor  atk   hoshino  Tshiroko    haruka      iori  nagisa_shiroko
#
#           a1        a2        a3       a4              as  outcome   rank
# ...

# %%
# table of all common strikers and attributes

# want name, def type, atk type, role in field, position, normal attack range, affinity (atk bonus, cover bonus encoded directly)
striker_attributes = pd.DataFrame([
    {'char':''
     }
])

# %%
# table of all common supporters and attributes

# %%
# table of color effectiveness
