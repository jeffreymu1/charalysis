# %%
import pandas as pd

# %%
path_to_csv = '../s9/data/s9.csv'

df = pd.read_csv(path_to_csv)

# %%
# <h1>MAINSTAYS<h1>

#%%%%% Strikers %%%%%#
# - hoshino
# - Tshiroko
# - haruka
# - iori
# - reisa
# - marina
# - saori
# - eimi
# - tsurugi
# - shun
# - nyharuna
# - nymutsuki
# - shanako

#%%%%% Specials %%%%%#
# - hibiki_shiroko
# - nagisa_shiroko
# - ayane_shiroko
# - saki_shiroko
# - ayane_nagisa
# - ayane_hibiki
# - hibiki_saki
# - minori_shiroko
# - nyserika_shiroko

# %%
### ADD ATK DATA
new_row = ['indoor', 'atk',
           
            # DEFENSE
            'hoshino', # d1
            'Tshiroko', # d2
            'haruka', # d3
            'iori', # d4
            'nagisa_shiroko', # ds

            # ATTACK
            'marina', # a1
            'iori', # a2
            'Tshiroko', # a3
            'hoshino', # a4
            'ayane_shiroko', # as

            3, # did you win?
            62 # rank (after atking)
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)

# %%
### ADD DEF DATA
new_row = ['indoor','def',
           
            # DEFENSE
            'hoshino', # d1
            'shun', # d2
            'Tshiroko', # d3
            'marina', # d4
            'ayane_shiroko', # ds

            # ATTACK
            'Tshiroko', # a1
            'marina', # a2
            'shun', # a3
            'hoshino', # a4
            'nagisa_shiroko', # as

            1, # did you win?
            ]

pd.DataFrame([new_row]).to_csv(path_to_csv, mode="a", index=False, header=False)
